# %%
import pandas as pd

# %%
df = pd.read_csv('/media/hrs/Storage/ubuntu_repo/Amazon-Reviews-Sentiment-Analysis/data_pipeline/data/labeled/labeled_aspect_data.csv')

# %%
df['price'] = pd.to_numeric(df['price'].replace("unknown", None), errors='coerce')
df['price_missing'] = df['price'].isna().astype(int)
df['price'] = df['price'].fillna(0).astype(float)

# %%
columns_to_order = ['relevant_sentences', 'price', 'price_missing', 'helpful_vote', 'verified_purchase']
new_columns_order = columns_to_order + [col for col in df.columns if col not in columns_to_order]
df = df[new_columns_order]

# %%
df.to_csv("input_2021_data.csv",index=False)
# Out:
#                                      relevant_sentences  price  price_missing  \
# 0                       -Material ultra thin and cheap.   0.00              1
# 1     Label says made in Honduras Material is very t...  38.77              0
# 2     The sunglass has not good quality both for fra...   0.00              1
# 3                                         Poor quality.   0.00              1
# 4                Maybe it was a one time quality error.   0.00              1
# ...                                                 ...    ...            ...
# 9256          This a great product for an amazing price   0.00              1
# 9257                               Super fast shipping!   0.00              1
# 9258  I like this purifier's style--white, clean, si...   0.00              1
# 9259        Unbelievable value compare at any pharamacy   0.00              1
# 9260     Good product, a bit expensive but worth the $.  36.00              0
#
#       helpful_vote  verified_purchase  rating  \
# 0                1               True       1
# 1                0               True       1
# 2                0               True       1
# 3                0               True       1
# 4                1               True       1
# ...            ...                ...     ...
# 9256             0               True       5
# 9257             0               True       5
# 9258             0               True       5
# 9259             0               True       5
# 9260             3               True       5
#
#                                                   title  \
# 0                          Good for gym, not for casual
# 1                        Not made in USA Cheap quality.
# 2                                   low quality product
# 3                                             Don't buy
# 4                           Good looking but was flawed
# ...                                                 ...
# 9256                                         Vitamine C
# 9257                                       Great flavor
# 9258                        Stylist Purifier works well
# 9259                                        Works great
# 9260  Definitely works!!! On my 4th bottle and will ...
#
#                                                    text        asin  \
# 0     -Material ultra thin and cheap. -The stitching...  B08H1LYCJ3
# 1     Shirt is not made in USA like advertised. Labe...  B07D1T1SS3
# 2     The sunglass has not good quality both for fra...  B07MB411VY
# 3     Don't buy. Poor quality. Light does NOT even w...  B08J7WKLTD
# 4     Pros: Very nice looking watch-looks even bette...  B08PQCZPRV
# ...                                                 ...         ...
# 9256          This a great product for an amazing price  B08GL33VL6
# 9257  Super fast shipping! My dog loves the flavor. ...  B0932P8R65
# 9258  I like this purifier's style--white, clean, si...  B09CDH8HXF
# 9259        Unbelievable value compare at any pharamacy  B09BQN1ZRJ
# 9260  Good product, a bit expensive but worth the $....  B010690Q4O
#
#      parent_asin  ... review_date_timestamp           main_category  \
# 0     B08H1LYCJ3  ...   2021-01-30 17:37:08          AMAZON FASHION
# 1     B07D1TD6T9  ...   2021-01-30 03:31:35          AMAZON FASHION
# 2     B07MB411VY  ...   2021-01-19 02:40:00          AMAZON FASHION
# 3     B08J7WKLTD  ...   2021-01-13 19:48:35          AMAZON FASHION
# 4     B08PQCZPRV  ...   2021-01-09 02:23:53          AMAZON FASHION
# ...          ...  ...                   ...                     ...
# 9256  B08GL33VL6  ...   2021-12-24 00:54:27  Health & Personal Care
# 9257  B0932P8R65  ...   2021-12-02 00:59:11  Health & Personal Care
# 9258  B09CDH8HXF  ...   2021-12-11 14:51:18  Health & Personal Care
# 9259  B09BQN1ZRJ  ...   2021-12-15 22:29:08  Health & Personal Care
# 9260  B010690Q4O  ...   2021-12-30 21:33:27  Health & Personal Care
#
#                                            product_name categories  \
# 0     COOFANDY Men's 3 Pack Tank Tops Cotton Perform...        NaN
# 1     Detroit Shirt Company Men's Dodge Scat Pack Tr...        NaN
# 2     CADIROZ Polarized Sunglasses for Men Driving M...        NaN
# 3     LED Light Up Mandalorian Helmet Colorful Glowi...        NaN
# 4     LIGE Men's Watches Automatic Mechanical Wrist ...        NaN
# ...                                                 ...        ...
# 9256  Vitamin C 500mg (per Serving) + Natural Energy...        NaN
# 9257  Kenn & Kitt Hip and Joint Supplement for Dogs ...        NaN
# 9258  Okaysou Air Purifiers for Home Large Room, Hig...        NaN
# 9259  MUNTO 12 Pack Replacement Toothbrush Heads Com...        NaN
# 9260        S5 Beta-ecdysterone Beta Ecdysterone 500 mg        NaN
#
#      average_rating  rating_number  review_month  year          aspect  \
# 0               4.0             37             1  2021            cost
# 1               4.8            179             1  2021         quality
# 2               3.0              2             1  2021         quality
# 3               2.7             95             1  2021         quality
# 4               3.5              6             1  2021         quality
# ...             ...            ...           ...   ...             ...
# 9256            4.9             41            12  2021            cost
# 9257            4.6             37            12  2021        delivery
# 9258            4.5           1203            12  2021  product_design
# 9259            4.0             28            12  2021            cost
# 9260            4.2            376            12  2021            cost
#
#       sentiment_label
# 0             NEUTRAL
# 1            NEGATIVE
# 2            NEGATIVE
# 3            NEGATIVE
# 4            NEGATIVE
# ...               ...
# 9256         POSITIVE
# 9257         POSITIVE
# 9258         POSITIVE
# 9259         POSITIVE
# 9260         POSITIVE
#
# [9261 rows x 22 columns]
