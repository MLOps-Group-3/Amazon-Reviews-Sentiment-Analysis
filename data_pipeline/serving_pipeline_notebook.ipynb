# %% [markdown]
# # Step 1: Reading the batch file

# %%
import pandas as pd

# File path
file_path = "/home/niresh/Amazon-Reviews-Sentiment-Analysis/project_pipeline/data/cleaned/cleaned_data.csv"

# Read the CSV file
data = pd.read_csv(file_path)

# Display the first few rows to verify the content
data.head()
# Out:
#    rating                           title  \
# 0       1  Horrible fit. Runs very small.
# 1       1                       Too small
# 2       1                         Hideous
# 3       1           Take it off the shelf
# 4       1                            Nope
#
#                                                 text        asin parent_asin  \
# 0  It runs super, super small. Not as described o...  B07S5YTLS6  B07S5YTLS6
# 1                                    Not fit to size  B07YDW61TP  B07YDW61TP
# 2          Looked like a boxy table cloth. Returned.  B07RFRDXX3  B07RFRDXX3
# 3        It is a flimsy, tacky, Total piece of junk.  B07WJSB7NW  B07WJSB7NW
# 4                           Fell out way to easily!!  B07F7HLTVP  B07F7HLTVP
#
#                         user_id      timestamp  helpful_vote  \
# 0  AFYDAEFBQG7ABFYIKYWGJEBYTOVA  1579539477541             0
# 1  AHGOHRIHM6CDYFMMH3XTAFUH3HAA  1577994486668             0
# 2  AFI2QIIDWYV2WLC3YDJQDCY4H6AQ  1578145640026             0
# 3  AEMMOLRDFMS2EFVGVUWI5DA5LNGA  1579558368267             3
# 4  AEJZOUKYY3XPTGHN7GDRKBKJCRNQ  1579394246114             0
#
#    verified_purchase review_date_timestamp   main_category  \
# 0               True   2020-01-20 16:57:57  AMAZON FASHION
# 1               True   2020-01-02 19:48:06  AMAZON FASHION
# 2               True   2020-01-04 13:47:20  AMAZON FASHION
# 3               True   2020-01-20 22:12:48  AMAZON FASHION
# 4               True   2020-01-19 00:37:26  AMAZON FASHION
#
#                                         product_name categories    price  \
# 0  SSOULM Women's Loose Fit Open Front Work Offic...        NaN  unknown
# 1  Men's Gym Stringer. No Pain Bodybuilding Muscl...        NaN  unknown
# 2  Biucly Women's Stylish Floral Printed V Neck T...        NaN  unknown
# 3  JOYMADE compact small mini folding travel umbr...        NaN  unknown
# 4  Incaton 20G Stainless Steel CZ Inlaid Nose Rin...        NaN  unknown
#
#    average_rating  rating_number  review_month  year
# 0             1.0              1             1  2020
# 1             3.7              2             1  2020
# 2             3.5              3             1  2020
# 3             4.2             13             1  2020
# 4             3.3             11             1  2020

# %% [markdown]
# # Step 2: Preprocessing the data

# %%
# Processing the data
data['text'] = data['text'].fillna('')
data['title'] = data['title'].fillna('')
data['price'] = pd.to_numeric(data['price'].replace("unknown", None), errors='coerce')
data['price_missing'] = data['price'].isna().astype(int)
data['price'] = data['price'].fillna(0).astype(float)
data['helpful_vote'] = data['helpful_vote'].fillna(0).astype(int)
data['verified_purchase'] = data['verified_purchase'].apply(lambda x: True if x else False)

# Display the first few rows of the processed data
data.head()
# Out:
#    rating                           title  \
# 0       1  Horrible fit. Runs very small.
# 1       1                       Too small
# 2       1                         Hideous
# 3       1           Take it off the shelf
# 4       1                            Nope
#
#                                                 text        asin parent_asin  \
# 0  It runs super, super small. Not as described o...  B07S5YTLS6  B07S5YTLS6
# 1                                    Not fit to size  B07YDW61TP  B07YDW61TP
# 2          Looked like a boxy table cloth. Returned.  B07RFRDXX3  B07RFRDXX3
# 3        It is a flimsy, tacky, Total piece of junk.  B07WJSB7NW  B07WJSB7NW
# 4                           Fell out way to easily!!  B07F7HLTVP  B07F7HLTVP
#
#                         user_id      timestamp  helpful_vote  \
# 0  AFYDAEFBQG7ABFYIKYWGJEBYTOVA  1579539477541             0
# 1  AHGOHRIHM6CDYFMMH3XTAFUH3HAA  1577994486668             0
# 2  AFI2QIIDWYV2WLC3YDJQDCY4H6AQ  1578145640026             0
# 3  AEMMOLRDFMS2EFVGVUWI5DA5LNGA  1579558368267             3
# 4  AEJZOUKYY3XPTGHN7GDRKBKJCRNQ  1579394246114             0
#
#    verified_purchase review_date_timestamp   main_category  \
# 0               True   2020-01-20 16:57:57  AMAZON FASHION
# 1               True   2020-01-02 19:48:06  AMAZON FASHION
# 2               True   2020-01-04 13:47:20  AMAZON FASHION
# 3               True   2020-01-20 22:12:48  AMAZON FASHION
# 4               True   2020-01-19 00:37:26  AMAZON FASHION
#
#                                         product_name categories  price  \
# 0  SSOULM Women's Loose Fit Open Front Work Offic...        NaN    0.0
# 1  Men's Gym Stringer. No Pain Bodybuilding Muscl...        NaN    0.0
# 2  Biucly Women's Stylish Floral Printed V Neck T...        NaN    0.0
# 3  JOYMADE compact small mini folding travel umbr...        NaN    0.0
# 4  Incaton 20G Stainless Steel CZ Inlaid Nose Rin...        NaN    0.0
#
#    average_rating  rating_number  review_month  year  price_missing
# 0             1.0              1             1  2020              1
# 1             3.7              2             1  2020              1
# 2             3.5              3             1  2020              1
# 3             4.2             13             1  2020              1
# 4             3.3             11             1  2020              1

# %% [markdown]
# # Step 3: Save to an output folder

# %%
# ### ONE TIME THING FOR TESTING
# # Filter data for the year 2020 and review month 10 (October)
# filtered_data = data[(data['year'] == 2020) & (data['review_month'] == 10)]

# filtered_data.head()

# %%
# Sample filtered data

# %%
# List of columns to appear first, in the desired order
first_columns = ["text", "price", "price_missing", "helpful_vote", "verified_purchase"]

# Get the list of all columns in the DataFrame
all_columns = data.columns.tolist()

# Remove the specified columns from the list of all columns
remaining_columns = [col for col in all_columns if col not in first_columns]

# Create the new column order by combining the specified columns and the remaining columns
new_column_order = first_columns + remaining_columns

# Reorder the DataFrame columns
data = data[new_column_order]

data.head()
# Out:
#                                                 text  price  price_missing  \
# 0  It runs super, super small. Not as described o...    0.0              1
# 1                                    Not fit to size    0.0              1
# 2          Looked like a boxy table cloth. Returned.    0.0              1
# 3        It is a flimsy, tacky, Total piece of junk.    0.0              1
# 4                           Fell out way to easily!!    0.0              1
#
#    helpful_vote  verified_purchase  rating                           title  \
# 0             0               True       1  Horrible fit. Runs very small.
# 1             0               True       1                       Too small
# 2             0               True       1                         Hideous
# 3             3               True       1           Take it off the shelf
# 4             0               True       1                            Nope
#
#          asin parent_asin                       user_id      timestamp  \
# 0  B07S5YTLS6  B07S5YTLS6  AFYDAEFBQG7ABFYIKYWGJEBYTOVA  1579539477541
# 1  B07YDW61TP  B07YDW61TP  AHGOHRIHM6CDYFMMH3XTAFUH3HAA  1577994486668
# 2  B07RFRDXX3  B07RFRDXX3  AFI2QIIDWYV2WLC3YDJQDCY4H6AQ  1578145640026
# 3  B07WJSB7NW  B07WJSB7NW  AEMMOLRDFMS2EFVGVUWI5DA5LNGA  1579558368267
# 4  B07F7HLTVP  B07F7HLTVP  AEJZOUKYY3XPTGHN7GDRKBKJCRNQ  1579394246114
#
#   review_date_timestamp   main_category  \
# 0   2020-01-20 16:57:57  AMAZON FASHION
# 1   2020-01-02 19:48:06  AMAZON FASHION
# 2   2020-01-04 13:47:20  AMAZON FASHION
# 3   2020-01-20 22:12:48  AMAZON FASHION
# 4   2020-01-19 00:37:26  AMAZON FASHION
#
#                                         product_name categories  \
# 0  SSOULM Women's Loose Fit Open Front Work Offic...        NaN
# 1  Men's Gym Stringer. No Pain Bodybuilding Muscl...        NaN
# 2  Biucly Women's Stylish Floral Printed V Neck T...        NaN
# 3  JOYMADE compact small mini folding travel umbr...        NaN
# 4  Incaton 20G Stainless Steel CZ Inlaid Nose Rin...        NaN
#
#    average_rating  rating_number  review_month  year
# 0             1.0              1             1  2020
# 1             3.7              2             1  2020
# 2             3.5              3             1  2020
# 3             4.2             13             1  2020
# 4             3.3             11             1  2020

# %%
# extracted_columns = filtered_data[["text", "price", "price_missing", "helpful_vote", "verified_purchase"]]

# %%
# Define the output file path
output_path = "/home/niresh/Amazon-Reviews-Sentiment-Analysis/project_pipeline/data/batch_processing_input/processed_batch_data.csv"

# Save the updated DataFrame to a CSV file
# data.to_csv(output_path, index=False)
data.to_csv(output_path, index=False)

print(f"Processed file saved to {output_path}")
# Out:
# Processed file saved to /home/niresh/Amazon-Reviews-Sentiment-Analysis/project_pipeline/data/batch_processing_input/processed_batch_data.csv

# %% [markdown]
# # Step 4: Uploading it to GCS bucket

# %%
import os
from google.cloud import storage

# Set the path to your service account key
service_account_path = "/home/niresh/Amazon-Reviews-Sentiment-Analysis/project_pipeline/config/amazonreviewssentimentanalysis-8dfde6e21c1d.json"
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = service_account_path

# Define your GCP bucket details
bucket_name = "model-deployment-from-airflow"
destination_blob_name = "batch_processing_input/Serving Batches/processed_batch_data.csv"  # Path in the bucket
local_file_path = "/home/niresh/Amazon-Reviews-Sentiment-Analysis/project_pipeline/data/batch_processing_input/processed_batch_data.csv"

# Upload the file to GCP bucket
def upload_to_gcp_bucket(bucket_name, destination_blob_name, local_file_path):
    client = storage.Client()
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)
    blob.upload_from_filename(local_file_path)
    print(f"File {local_file_path} uploaded to {destination_blob_name} in bucket {bucket_name}.")

# Call the function
upload_to_gcp_bucket(bucket_name, destination_blob_name, local_file_path)
# Out:
# File /home/niresh/Amazon-Reviews-Sentiment-Analysis/project_pipeline/data/batch_processing_input/processed_batch_data.csv uploaded to batch_processing_input/Serving Batches/processed_batch_data.csv in bucket model-deployment-from-airflow.

# %% [markdown]
# # Step 5: Creating a BQ table

# %%
from google.cloud import bigquery
import os

# Set GCP credentials (if not already set in the environment)
# os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/home/niresh/Amazon-Reviews-Sentiment-Analysis/project_pipeline/config/amazonreviewssentimentanalysis-8dfde6e21c1d.json"

# Initialize BigQuery client
client = bigquery.Client()

# Define the GCS file and BigQuery table details
gcs_uri = "gs://model-deployment-from-airflow/batch_processing_input/Serving Batches/aspect_batch/input_2021_data_2.csv"
project_id = "amazonreviewssentimentanalysis"
dataset_id = "amazon_reviews_sentiment"
table_id = "aspect_data_2021"

# Define BigQuery table full path
table_ref = f"{project_id}.{dataset_id}.{table_id}"

# Define load job configuration
job_config = bigquery.LoadJobConfig(
    source_format=bigquery.SourceFormat.CSV,
    skip_leading_rows=1,  # Skip the header row
    autodetect=True,  # Auto-detect schema
    write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE  # Overwrite the table
)

# Load data from GCS to BigQuery
load_job = client.load_table_from_uri(
    gcs_uri,
    table_ref,
    job_config=job_config
)  # Make an API request.

# Wait for the load job to complete
load_job.result()

print(f"Loaded data from {gcs_uri} to {table_ref}.")
# Out:
# /home/hrs/anaconda3/envs/mlops_exp/lib/python3.12/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /home/hrs/anaconda3/envs/mlops_exp/lib/python3.12/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# Loaded data from gs://model-deployment-from-airflow/batch_processing_input/Serving Batches/aspect_batch/input_2021_data_2.csv to amazonreviewssentimentanalysis.amazon_reviews_sentiment.aspect_data_2021.

# %% [markdown]
# # Step 6: Submitting Batch Prediction Job

# %%
from google.cloud import aiplatform

# Initialize the Vertex AI client
aiplatform.init(project="amazonreviewssentimentanalysis", location="us-central1")
# project_id = "amazonreviewssentimentanalysis"
# dataset_id = "amazon_reviews_sentiment"
# table_id = "aspect_data_2021"
# table_id = "aspect_data_2022_2023"


# Define the model name and input/output details
model_name = "projects/amazonreviewssentimentanalysis/locations/us-central1/models/7777458171236319232"
input_table = f"bq://{project_id}.{dataset_id}.{table_id}"
# output_table = "bq://amazonreviewssentimentanalysis.amazon_reviews_sentiment.processed_batch_data_w_predictions"
output_table = f"bq://{project_id}.{dataset_id}.{table_id}_preds"

batch_prediction_name = "Amazon-Month-Batch-BQ-rearranged"

# Initialize the model using the model name
model = aiplatform.Model(model_name=model_name)

# Configure and run the batch prediction job
batch_prediction_job = model.batch_predict(
    job_display_name=batch_prediction_name,
    bigquery_source=input_table,
    bigquery_destination_prefix=output_table,
    machine_type="n1-standard-4",
    starting_replica_count=2,
    max_replica_count=2,
    sync=True
)

# Print a message when the job is complete
print(f"Batch Prediction Job {batch_prediction_name} completed.")
print(f"Prediction results saved to: {batch_prediction_job.output_info.bigquery_output_table}")
# Out:
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/661148801406/locations/us-central1/batchPredictionJobs/8167706974289395712
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/661148801406/locations/us-central1/batchPredictionJobs/8167706974289395712')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/8167706974289395712?project=661148801406
# BatchPredictionJob projects/661148801406/locations/us-central1/batchPredictionJobs/8167706974289395712 current state:
# 3
# BatchPredictionJob projects/661148801406/locations/us-central1/batchPredictionJobs/8167706974289395712 current state:
# 3
# BatchPredictionJob projects/661148801406/locations/us-central1/batchPredictionJobs/8167706974289395712 current state:
# 3
# BatchPredictionJob projects/661148801406/locations/us-central1/batchPredictionJobs/8167706974289395712 current state:
# 3
# BatchPredictionJob projects/661148801406/locations/us-central1/batchPredictionJobs/8167706974289395712 current state:
# 3
# BatchPredictionJob projects/661148801406/locations/us-central1/batchPredictionJobs/8167706974289395712 current state:
# 3
# BatchPredictionJob projects/661148801406/locations/us-central1/batchPredictionJobs/8167706974289395712 current state:
# 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 23
#      20 model = aiplatform.Model(model_name=model_name)
#      22 # Configure and run the batch prediction job
# ---> 23 batch_prediction_job = model.batch_predict(
#      24     job_display_name=batch_prediction_name,
#      25     bigquery_source=input_table,
#      26     bigquery_destination_prefix=output_table,
#      27     machine_type="n1-standard-4",
#      28     starting_replica_count=2,
#      29     max_replica_count=2,
#      30     sync=True
#      31 )
#      33 # Print a message when the job is complete
#      34 print(f"Batch Prediction Job {batch_prediction_name} completed.")
#
# File ~/anaconda3/envs/mlops_exp/lib/python3.12/site-packages/google/cloud/aiplatform/models.py:5709, in Model.batch_predict(self, job_display_name, gcs_source, bigquery_source, instances_format, gcs_destination_prefix, bigquery_destination_prefix, predictions_format, model_parameters, machine_type, accelerator_type, accelerator_count, starting_replica_count, max_replica_count, generate_explanation, explanation_metadata, explanation_parameters, labels, credentials, encryption_spec_key_name, sync, create_request_timeout, batch_size, service_account)
#    5512 def batch_predict(
#    5513     self,
#    5514     job_display_name: Optional[str] = None,
#    (...)
#    5538     service_account: Optional[str] = None,
#    5539 ) -> jobs.BatchPredictionJob:
#    5540     """Creates a batch prediction job using this Model and outputs
#    5541     prediction results to the provided destination prefix in the specified
#    5542     `predictions_format`. One source and one destination prefix are
#    (...)
#    5706             Instantiated representation of the created batch prediction job.
#    5707     """
# -> 5709     return jobs.BatchPredictionJob.create(
#    5710         job_display_name=job_display_name,
#    5711         model_name=self,
#    5712         instances_format=instances_format,
#    5713         predictions_format=predictions_format,
#    5714         gcs_source=gcs_source,
#    5715         bigquery_source=bigquery_source,
#    5716         gcs_destination_prefix=gcs_destination_prefix,
#    5717         bigquery_destination_prefix=bigquery_destination_prefix,
#    5718         model_parameters=model_parameters,
#    5719         machine_type=machine_type,
#    5720         accelerator_type=accelerator_type,
#    5721         accelerator_count=accelerator_count,
#    5722         starting_replica_count=starting_replica_count,
#    5723         max_replica_count=max_replica_count,
#    5724         batch_size=batch_size,
#    5725         generate_explanation=generate_explanation,
#    5726         explanation_metadata=explanation_metadata,
#    5727         explanation_parameters=explanation_parameters,
#    5728         labels=labels,
#    5729         project=self.project,
#    5730         location=self.location,
#    5731         credentials=credentials or self.credentials,
#    5732         encryption_spec_key_name=encryption_spec_key_name,
#    5733         sync=sync,
#    5734         create_request_timeout=create_request_timeout,
#    5735         service_account=service_account,
#    5736     )
#
# File ~/anaconda3/envs/mlops_exp/lib/python3.12/site-packages/google/cloud/aiplatform/jobs.py:620, in BatchPredictionJob.create(cls, job_display_name, model_name, instances_format, predictions_format, gcs_source, bigquery_source, gcs_destination_prefix, bigquery_destination_prefix, model_parameters, machine_type, accelerator_type, accelerator_count, starting_replica_count, max_replica_count, generate_explanation, explanation_metadata, explanation_parameters, labels, project, location, credentials, encryption_spec_key_name, sync, create_request_timeout, batch_size, model_monitoring_objective_config, model_monitoring_alert_config, analysis_instance_schema_uri, service_account)
#     391 @classmethod
#     392 def create(
#     393     cls,
#    (...)
#     429     service_account: Optional[str] = None,
#     430 ) -> "BatchPredictionJob":
#     431     """Create a batch prediction job.
#     432
#     433     Args:
#    (...)
#     618             Instantiated representation of the created batch prediction job.
#     619     """
# --> 620     return cls._submit_impl(
#     621         job_display_name=job_display_name,
#     622         model_name=model_name,
#     623         instances_format=instances_format,
#     624         predictions_format=predictions_format,
#     625         gcs_source=gcs_source,
#     626         bigquery_source=bigquery_source,
#     627         gcs_destination_prefix=gcs_destination_prefix,
#     628         bigquery_destination_prefix=bigquery_destination_prefix,
#     629         model_parameters=model_parameters,
#     630         machine_type=machine_type,
#     631         accelerator_type=accelerator_type,
#     632         accelerator_count=accelerator_count,
#     633         starting_replica_count=starting_replica_count,
#     634         max_replica_count=max_replica_count,
#     635         generate_explanation=generate_explanation,
#     636         explanation_metadata=explanation_metadata,
#     637         explanation_parameters=explanation_parameters,
#     638         labels=labels,
#     639         project=project,
#     640         location=location,
#     641         credentials=credentials,
#     642         encryption_spec_key_name=encryption_spec_key_name,
#     643         sync=sync,
#     644         create_request_timeout=create_request_timeout,
#     645         batch_size=batch_size,
#     646         model_monitoring_objective_config=model_monitoring_objective_config,
#     647         model_monitoring_alert_config=model_monitoring_alert_config,
#     648         analysis_instance_schema_uri=analysis_instance_schema_uri,
#     649         service_account=service_account,
#     650         # Main distinction of `create` vs `submit`:
#     651         wait_for_completion=True,
#     652     )
#
# File ~/anaconda3/envs/mlops_exp/lib/python3.12/site-packages/google/cloud/aiplatform/jobs.py:1337, in BatchPredictionJob._submit_impl(cls, job_display_name, model_name, instances_format, predictions_format, gcs_source, bigquery_source, gcs_destination_prefix, bigquery_destination_prefix, model_parameters, machine_type, accelerator_type, accelerator_count, starting_replica_count, max_replica_count, generate_explanation, explanation_metadata, explanation_parameters, labels, project, location, credentials, encryption_spec_key_name, sync, create_request_timeout, batch_size, model_monitoring_objective_config, model_monitoring_alert_config, analysis_instance_schema_uri, service_account, wait_for_completion)
#    1334     gapic_batch_prediction_job.model_monitoring_config = gapic_mm_config
#    1336 # TODO(b/242108750): remove temporary logic once model monitoring for batch prediction is GA
# -> 1337 return cls._submit_and_optionally_wait_with_sync_support(
#    1338     empty_batch_prediction_job=empty_batch_prediction_job,
#    1339     model_or_model_name=model_name,
#    1340     gca_batch_prediction_job=gapic_batch_prediction_job,
#    1341     generate_explanation=generate_explanation,
#    1342     sync=sync,
#    1343     create_request_timeout=create_request_timeout,
#    1344     wait_for_completion=wait_for_completion,
#    1345 )
#
# File ~/anaconda3/envs/mlops_exp/lib/python3.12/site-packages/google/cloud/aiplatform/base.py:863, in optional_sync.<locals>.optional_run_in_thread.<locals>.wrapper(*args, **kwargs)
#     861     if self:
#     862         VertexAiResourceNounWithFutureManager.wait(self)
# --> 863     return method(*args, **kwargs)
#     865 # callbacks to call within the Future (in same Thread)
#     866 internal_callbacks = []
#
# File ~/anaconda3/envs/mlops_exp/lib/python3.12/site-packages/google/cloud/aiplatform/jobs.py:1422, in BatchPredictionJob._submit_and_optionally_wait_with_sync_support(cls, empty_batch_prediction_job, model_or_model_name, gca_batch_prediction_job, generate_explanation, sync, create_request_timeout, wait_for_completion)
#    1418 _LOGGER.info(
#    1419     "View Batch Prediction Job:\n%s" % batch_prediction_job._dashboard_uri()
#    1420 )
#    1421 if wait_for_completion:
# -> 1422     batch_prediction_job._block_until_complete()
#    1424 return batch_prediction_job
#
# File ~/anaconda3/envs/mlops_exp/lib/python3.12/site-packages/google/cloud/aiplatform/jobs.py:244, in _Job._block_until_complete(self)
#     242         log_wait = min(log_wait * _WAIT_TIME_MULTIPLIER, _MAX_WAIT_TIME)
#     243         previous_time = current_time
# --> 244     time.sleep(_JOB_WAIT_TIME)
#     246 self._log_job_state()
#     248 # Error is only populated when the job state is
#     249 # JOB_STATE_FAILED or JOB_STATE_CANCELLED.
#
# KeyboardInterrupt:

# %% [markdown]
# # Step 7: Creating Output Table in the Required Format

# %%
from google.cloud import bigquery
import os

# Set GCP credentials (if not already set in the environment)
# os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/home/niresh/Amazon-Reviews-Sentiment-Analysis/project_pipeline/config/amazonreviewssentimentanalysis-8dfde6e21c1d.json"

print("Starting clean_prediction_results function")

client = bigquery.Client()

project_id = "amazonreviewssentimentanalysis"
dataset_id = "amazon_reviews_sentiment"
table_id = "aspect_data_2021"

query = f"""
DROP TABLE IF EXISTS `{project_id}.{dataset_id}.{table_id}_preds_clean`;
CREATE TABLE `{project_id}.{dataset_id}.{table_id}_preds_clean` AS
SELECT * EXCEPT(prediction),
  JSON_EXTRACT_SCALAR(prediction, '$[0]') AS predicted_sentiment_label,
  CAST(JSON_EXTRACT_SCALAR(prediction, '$[1].POS') AS FLOAT64) AS POS_confidence,
  CAST(JSON_EXTRACT_SCALAR(prediction, '$[1].NEU') AS FLOAT64) AS NEU_confidence,
  CAST(JSON_EXTRACT_SCALAR(prediction, '$[1].NEG') AS FLOAT64) AS NEG_confidence
FROM `{project_id}.{dataset_id}.{table_id}_preds`;
"""

print("Executing SQL query to clean prediction results")

job = client.query(query)
job.result()  # Wait for the query to finish

print("clean_prediction_results function completed successfully")
# Out:
# Starting clean_prediction_results function
# /home/hrs/anaconda3/envs/mlops_exp/lib/python3.12/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /home/hrs/anaconda3/envs/mlops_exp/lib/python3.12/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# Executing SQL query to clean prediction results
# clean_prediction_results function completed successfully

# %% [markdown]
# ### Test with monitoring

# %%
# from google.cloud import aiplatform
# # from google.cloud.aiplatform.v1 import ModelMonitoringObjectiveConfig
# # Initialize the Vertex AI client
# aiplatform.init(project="amazonreviewssentimentanalysis", location="us-central1")

# # Define the model name and input/output details
# model_name = "projects/amazonreviewssentimentanalysis/locations/us-central1/models/7777458171236319232"
# input_table = "bq://amazonreviewssentimentanalysis.amazon_reviews_sentiment.processed_batch_data"
# output_table = "bq://amazonreviewssentimentanalysis.amazon_reviews_sentiment.processed_batch_data_w_predictions_hrs"
# batch_prediction_name = "Amazon-Month-Batch-BQ-rearranged-hrs"

# # Create the batch prediction job
# batch_prediction_job = aiplatform.BatchPredictionJob.create(
#     job_display_name=batch_prediction_name,
#     model_name=model_name,
#     instances_format="bigquery",
#     predictions_format="bigquery",
#     bigquery_source=input_table,
#     bigquery_destination_prefix=output_table,
#     model_parameters=None,
#     machine_type="n1-standard-4",
#     accelerator_type=None,
#     accelerator_count=None,
#     starting_replica_count=1,
#     max_replica_count=10,
#     generate_explanation=False,
#     explanation_metadata=None,
#     explanation_parameters=None,
#     encryption_spec_key_name=None,
#     sync=True,
#     model_monitoring_objective_config=None,
#     model_monitoring_alert_config=None,
# )

# # Wait for the job to complete
# batch_prediction_job.wait()

# print(f"Batch prediction job completed with state: {batch_prediction_job.state}")
# print(f"Prediction results saved to: {batch_prediction_job.output_info.bigquery_output_dataset}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 13
#      10 batch_prediction_name = "Amazon-Month-Batch-BQ-rearranged-hrs"
#      12 # Create the batch prediction job
# ---> 13 batch_prediction_job = aiplatform.BatchPredictionJob.create(
#      14     job_display_name=batch_prediction_name,
#      15     model_name=model_name,
#      16     instances_format="bigquery",
#      17     predictions_format="bigquery",
#      18     bigquery_source=input_table,
#      19     bigquery_destination_prefix=output_table,
#      20     model_parameters=None,
#      21     machine_type="n1-standard-4",
#      22     accelerator_type=None,
#      23     accelerator_count=None,
#      24     starting_replica_count=1,
#      25     max_replica_count=10,
#      26     generate_explanation=False,
#      27     explanation_metadata=None,
#      28     explanation_parameters=None,
#      29     encryption_spec_key_name=None,
#      30     sync=True,
#      31     model_monitoring_objective_config=model_monitoring_objective_config,
#      32     model_monitoring_alert_config=alert_config,
#      33 )
#      35 # Wait for the job to complete
#      36 batch_prediction_job.wait()
#
# File ~/anaconda3/envs/mlops_pipeline/lib/python3.9/site-packages/google/cloud/aiplatform/jobs.py:620, in BatchPredictionJob.create(cls, job_display_name, model_name, instances_format, predictions_format, gcs_source, bigquery_source, gcs_destination_prefix, bigquery_destination_prefix, model_parameters, machine_type, accelerator_type, accelerator_count, starting_replica_count, max_replica_count, generate_explanation, explanation_metadata, explanation_parameters, labels, project, location, credentials, encryption_spec_key_name, sync, create_request_timeout, batch_size, model_monitoring_objective_config, model_monitoring_alert_config, analysis_instance_schema_uri, service_account)
#     391 @classmethod
#     392 def create(
#     393     cls,
#    (...)
#     429     service_account: Optional[str] = None,
#     430 ) -> "BatchPredictionJob":
#     431     """Create a batch prediction job.
#     432
#     433     Args:
#    (...)
#     618             Instantiated representation of the created batch prediction job.
#     619     """
# --> 620     return cls._submit_impl(
#     621         job_display_name=job_display_name,
#     622         model_name=model_name,
#     623         instances_format=instances_format,
#     624         predictions_format=predictions_format,
#     625         gcs_source=gcs_source,
#     626         bigquery_source=bigquery_source,
#     627         gcs_destination_prefix=gcs_destination_prefix,
#     628         bigquery_destination_prefix=bigquery_destination_prefix,
#     629         model_parameters=model_parameters,
#     630         machine_type=machine_type,
#     631         accelerator_type=accelerator_type,
#     632         accelerator_count=accelerator_count,
#     633         starting_replica_count=starting_replica_count,
#     634         max_replica_count=max_replica_count,
#     635         generate_explanation=generate_explanation,
#     636         explanation_metadata=explanation_metadata,
#     637         explanation_parameters=explanation_parameters,
#     638         labels=labels,
#     639         project=project,
#     640         location=location,
#     641         credentials=credentials,
#     642         encryption_spec_key_name=encryption_spec_key_name,
#     643         sync=sync,
#     644         create_request_timeout=create_request_timeout,
#     645         batch_size=batch_size,
#     646         model_monitoring_objective_config=model_monitoring_objective_config,
#     647         model_monitoring_alert_config=model_monitoring_alert_config,
#     648         analysis_instance_schema_uri=analysis_instance_schema_uri,
#     649         service_account=service_account,
#     650         # Main distinction of `create` vs `submit`:
#     651         wait_for_completion=True,
#     652     )
#
# File ~/anaconda3/envs/mlops_pipeline/lib/python3.9/site-packages/google/cloud/aiplatform/jobs.py:1326, in BatchPredictionJob._submit_impl(cls, job_display_name, model_name, instances_format, predictions_format, gcs_source, bigquery_source, gcs_destination_prefix, bigquery_destination_prefix, model_parameters, machine_type, accelerator_type, accelerator_count, starting_replica_count, max_replica_count, generate_explanation, explanation_metadata, explanation_parameters, labels, project, location, credentials, encryption_spec_key_name, sync, create_request_timeout, batch_size, model_monitoring_objective_config, model_monitoring_alert_config, analysis_instance_schema_uri, service_account, wait_for_completion)
#    1323     if model_monitoring_alert_config is not None:
#    1324         model_monitoring_alert_config._config_for_bp = True
#    1325     gapic_mm_config = gca_model_monitoring_v1beta1.ModelMonitoringConfig(
# -> 1326         objective_configs=[model_monitoring_objective_config.as_proto()],
#    1327         alert_config=model_monitoring_alert_config.as_proto()
#    1328         if model_monitoring_alert_config is not None
#    1329         else None,
#    1330         analysis_instance_schema_uri=analysis_instance_schema_uri
#    1331         if analysis_instance_schema_uri is not None
#    1332         else None,
#    1333     )
#    1334     gapic_batch_prediction_job.model_monitoring_config = gapic_mm_config
#    1336 # TODO(b/242108750): remove temporary logic once model monitoring for batch prediction is GA
#
# File ~/anaconda3/envs/mlops_pipeline/lib/python3.9/site-packages/proto/message.py:877, in Message.__getattr__(self, key)
#     875 (key, pb_type) = self._get_pb_type_from_key(key)
#     876 if pb_type is None:
# --> 877     raise AttributeError(
#     878         "Unknown field for {}: {}".format(self.__class__.__name__, key)
#     879     )
#     880 pb_value = getattr(self._pb, key)
#     881 marshal = self._meta.marshal
#
# AttributeError: Unknown field for ModelMonitoringObjectiveConfig: as_proto

# %%
model_monitoring_objective_config = {
    "training_dataset": {
        "gcs_source": {"uris": ["gs://model-deployment-from-airflow/batch_processing_input/train.csv"]},
        "data_format": "csv",
        "target_field": "price"
    },
    "training_prediction_skew_detection_config": {
        "skew_thresholds": {
            "text": {"value": 0.3},
            "price_missing": {"value": 0.1},
            "helpful_vote": {"value": 0.2},
            "verified_purchase": {"value": 0.1}
        }
    },
    "prediction_drift_detection_config": {
        "drift_thresholds": {
            "text": {"value": 0.3},
            "price_missing": {"value": 0.1},
            "helpful_vote": {"value": 0.2},
            "verified_purchase": {"value": 0.1}
        }
    }
}

# %%
from google.cloud.aiplatform_v1.types import ModelMonitoringObjectiveConfig, GcsSource, ThresholdConfig

# %%
# from google.cloud.aiplatform_v1.types import (
#     ModelMonitoringObjectiveConfig,
#     ThresholdConfig,
#     GcsSource,
#     ModelMonitoringAlertConfig
# )

# model_monitoring_objective_config = ModelMonitoringObjectiveConfig(
#     training_dataset=ModelMonitoringObjectiveConfig.TrainingDataset(
#         gcs_source=GcsSource(uris=["gs://model-deployment-from-airflow/batch_processing_input/train.csv"]),
#         data_format="csv",
#         target_field="price"
#     )
#     # )
#     ,
#     training_prediction_skew_detection_config=ModelMonitoringObjectiveConfig.TrainingPredictionSkewDetectionConfig(
#         skew_thresholds={
#             "text": ThresholdConfig(value=0.3),
#             "price_missing": ThresholdConfig(value=0.1),
#             "helpful_vote": ThresholdConfig(value=0.2),
#             "verified_purchase": ThresholdConfig(value=0.1)
#         }
#     ),
#     prediction_drift_detection_config=ModelMonitoringObjectiveConfig.PredictionDriftDetectionConfig(
#         drift_thresholds={
#             "text": ThresholdConfig(value=0.3),
#             "price_missing": ThresholdConfig(value=0.1),
#             "helpful_vote": ThresholdConfig(value=0.2),
#             "verified_purchase": ThresholdConfig(value=0.1)
#         }
#     )
# )

# alert_config = ModelMonitoringAlertConfig(
#     email_alert_config=ModelMonitoringAlertConfig.EmailAlertConfig(
#         user_emails=["@gmail.com"]
#     )
# )

# %%
model_monitoring_objective_config
# Out:
# training_dataset {
#   data_format: "csv"
#   gcs_source {
#     uris: "gs://model-deployment-from-airflow/batch_processing_input/train.csv"
#   }
#   target_field: "price"
# }
# training_prediction_skew_detection_config {
#   skew_thresholds {
#     key: "helpful_vote"
#     value {
#       value: 0.2
#     }
#   }
#   skew_thresholds {
#     key: "price_missing"
#     value {
#       value: 0.1
#     }
#   }
#   skew_thresholds {
#     key: "text"
#     value {
#       value: 0.3
#     }
#   }
#   skew_thresholds {
#     key: "verified_purchase"
#     value {
#       value: 0.1
#     }
#   }
# }
# prediction_drift_detection_config {
#   drift_thresholds {
#     key: "helpful_vote"
#     value {
#       value: 0.2
#     }
#   }
#   drift_thresholds {
#     key: "price_missing"
#     value {
#       value: 0.1
#     }
#   }
#   drift_thresholds {
#     key: "text"
#     value {
#       value: 0.3
#     }
#   }
#   drift_thresholds {
#     key: "verified_purchase"
#     value {
#       value: 0.1
#     }
#   }
# }

# %%
alert_config
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 alert_config
#
# NameError: name 'alert_config' is not defined

# %%
# from google.cloud import aiplatform
# # from google.cloud.aiplatform.v1 import ModelMonitoringObjectiveConfig
# # Initialize the Vertex AI client
# aiplatform.init(project="amazonreviewssentimentanalysis", location="us-central1")

# # Define the model name and input/output details
# model_name = "projects/amazonreviewssentimentanalysis/locations/us-central1/models/7777458171236319232"
# input_table = "bq://amazonreviewssentimentanalysis.amazon_reviews_sentiment.processed_batch_data"
# output_table = "bq://amazonreviewssentimentanalysis.amazon_reviews_sentiment.processed_batch_data_w_predictions_hrs"
# batch_prediction_name = "Amazon-Month-Batch-BQ-rearranged-hrs"

# # Create the batch prediction job
# batch_prediction_job = aiplatform.BatchPredictionJob.create(
#     job_display_name=batch_prediction_name,
#     model_name=model_name,
#     instances_format="bigquery",
#     predictions_format="bigquery",
#     bigquery_source=input_table,
#     bigquery_destination_prefix=output_table,
#     model_parameters=None,
#     machine_type="n1-standard-4",
#     accelerator_type=None,
#     accelerator_count=None,
#     starting_replica_count=1,
#     max_replica_count=10,
#     generate_explanation=False,
#     explanation_metadata=None,
#     explanation_parameters=None,
#     encryption_spec_key_name=None,
#     sync=True,
#     model_monitoring_objective_config=model_monitoring_objective_config,
#     model_monitoring_alert_config=alert_config,
# )

# # Wait for the job to complete
# batch_prediction_job.wait()

# print(f"Batch prediction job completed with state: {batch_prediction_job.state}")
# print(f"Prediction results saved to: {batch_prediction_job.output_info.bigquery_output_dataset}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 13
#      10 batch_prediction_name = "Amazon-Month-Batch-BQ-rearranged-hrs"
#      12 # Create the batch prediction job
# ---> 13 batch_prediction_job = aiplatform.BatchPredictionJob.create(
#      14     job_display_name=batch_prediction_name,
#      15     model_name=model_name,
#      16     instances_format="bigquery",
#      17     predictions_format="bigquery",
#      18     bigquery_source=input_table,
#      19     bigquery_destination_prefix=output_table,
#      20     model_parameters=None,
#      21     machine_type="n1-standard-4",
#      22     accelerator_type=None,
#      23     accelerator_count=None,
#      24     starting_replica_count=1,
#      25     max_replica_count=10,
#      26     generate_explanation=False,
#      27     explanation_metadata=None,
#      28     explanation_parameters=None,
#      29     encryption_spec_key_name=None,
#      30     sync=True,
#      31     model_monitoring_objective_config=model_monitoring_objective_config,
#      32     model_monitoring_alert_config=alert_config,
#      33 )
#      35 # Wait for the job to complete
#      36 batch_prediction_job.wait()
#
# File ~/anaconda3/envs/mlops_pipeline/lib/python3.9/site-packages/google/cloud/aiplatform/jobs.py:620, in BatchPredictionJob.create(cls, job_display_name, model_name, instances_format, predictions_format, gcs_source, bigquery_source, gcs_destination_prefix, bigquery_destination_prefix, model_parameters, machine_type, accelerator_type, accelerator_count, starting_replica_count, max_replica_count, generate_explanation, explanation_metadata, explanation_parameters, labels, project, location, credentials, encryption_spec_key_name, sync, create_request_timeout, batch_size, model_monitoring_objective_config, model_monitoring_alert_config, analysis_instance_schema_uri, service_account)
#     391 @classmethod
#     392 def create(
#     393     cls,
#    (...)
#     429     service_account: Optional[str] = None,
#     430 ) -> "BatchPredictionJob":
#     431     """Create a batch prediction job.
#     432
#     433     Args:
#    (...)
#     618             Instantiated representation of the created batch prediction job.
#     619     """
# --> 620     return cls._submit_impl(
#     621         job_display_name=job_display_name,
#     622         model_name=model_name,
#     623         instances_format=instances_format,
#     624         predictions_format=predictions_format,
#     625         gcs_source=gcs_source,
#     626         bigquery_source=bigquery_source,
#     627         gcs_destination_prefix=gcs_destination_prefix,
#     628         bigquery_destination_prefix=bigquery_destination_prefix,
#     629         model_parameters=model_parameters,
#     630         machine_type=machine_type,
#     631         accelerator_type=accelerator_type,
#     632         accelerator_count=accelerator_count,
#     633         starting_replica_count=starting_replica_count,
#     634         max_replica_count=max_replica_count,
#     635         generate_explanation=generate_explanation,
#     636         explanation_metadata=explanation_metadata,
#     637         explanation_parameters=explanation_parameters,
#     638         labels=labels,
#     639         project=project,
#     640         location=location,
#     641         credentials=credentials,
#     642         encryption_spec_key_name=encryption_spec_key_name,
#     643         sync=sync,
#     644         create_request_timeout=create_request_timeout,
#     645         batch_size=batch_size,
#     646         model_monitoring_objective_config=model_monitoring_objective_config,
#     647         model_monitoring_alert_config=model_monitoring_alert_config,
#     648         analysis_instance_schema_uri=analysis_instance_schema_uri,
#     649         service_account=service_account,
#     650         # Main distinction of `create` vs `submit`:
#     651         wait_for_completion=True,
#     652     )
#
# File ~/anaconda3/envs/mlops_pipeline/lib/python3.9/site-packages/google/cloud/aiplatform/jobs.py:1326, in BatchPredictionJob._submit_impl(cls, job_display_name, model_name, instances_format, predictions_format, gcs_source, bigquery_source, gcs_destination_prefix, bigquery_destination_prefix, model_parameters, machine_type, accelerator_type, accelerator_count, starting_replica_count, max_replica_count, generate_explanation, explanation_metadata, explanation_parameters, labels, project, location, credentials, encryption_spec_key_name, sync, create_request_timeout, batch_size, model_monitoring_objective_config, model_monitoring_alert_config, analysis_instance_schema_uri, service_account, wait_for_completion)
#    1323     if model_monitoring_alert_config is not None:
#    1324         model_monitoring_alert_config._config_for_bp = True
#    1325     gapic_mm_config = gca_model_monitoring_v1beta1.ModelMonitoringConfig(
# -> 1326         objective_configs=[model_monitoring_objective_config.as_proto()],
#    1327         alert_config=model_monitoring_alert_config.as_proto()
#    1328         if model_monitoring_alert_config is not None
#    1329         else None,
#    1330         analysis_instance_schema_uri=analysis_instance_schema_uri
#    1331         if analysis_instance_schema_uri is not None
#    1332         else None,
#    1333     )
#    1334     gapic_batch_prediction_job.model_monitoring_config = gapic_mm_config
#    1336 # TODO(b/242108750): remove temporary logic once model monitoring for batch prediction is GA
#
# File ~/anaconda3/envs/mlops_pipeline/lib/python3.9/site-packages/proto/message.py:877, in Message.__getattr__(self, key)
#     875 (key, pb_type) = self._get_pb_type_from_key(key)
#     876 if pb_type is None:
# --> 877     raise AttributeError(
#     878         "Unknown field for {}: {}".format(self.__class__.__name__, key)
#     879     )
#     880 pb_value = getattr(self._pb, key)
#     881 marshal = self._meta.marshal
#
# AttributeError: Unknown field for ModelMonitoringObjectiveConfig: as_proto

# %%
# from google.cloud import aiplatform
# from google.cloud.aiplatform.model_monitoring.objective import ObjectiveConfig, SkewDetectionConfig, DriftDetectionConfig
# from google.cloud.aiplatform.model_monitoring import EmailAlertConfig

# # Initialize the Vertex AI client
# aiplatform.init(project="amazonreviewssentimentanalysis", location="us-central1")

# # Define the model name and input/output details
# model_name = "projects/amazonreviewssentimentanalysis/locations/us-central1/models/7777458171236319232"
# input_table = "bq://amazonreviewssentimentanalysis.batch_processing_input_batch_test_data.filtered_2020_01_data_rearranged"
# output_table = "bq://amazonreviewssentimentanalysis.batch_processing_input_batch_test_data.filtered_2020_01_data_rearranged_pred_hrs"
# batch_prediction_name = "Amazon-Month-Batch-BQ-rearranged-hrs"
# train_table = "bq://amazonreviewssentimentanalysis.batch_processing_input_batch_test_data.batch_processing_input_train"

# # Define the skew detection config
# skew_detection_config = SkewDetectionConfig(
#     data_source=train_table,
#     # target_field="price",
#     # data_format="csv",
#     skew_thresholds={
#         "text": 0.3,
#         "price_missing": 0.1,
#         "helpful_vote": 0.2,
#         "verified_purchase": 0.1
#     }
# )

# # Define the drift detection config
# drift_detection_config = DriftDetectionConfig(
#     drift_thresholds={
#         "text": 0.3,
#         "price_missing": 0.1,
#         "helpful_vote": 0.2,
#         "verified_purchase": 0.1
#     }
# )

# # Create the objective config
# model_monitoring_objective_config = ObjectiveConfig(
#     skew_detection_config=skew_detection_config,
#     drift_detection_config=drift_detection_config
# )

# # Create the email alert configuration
# model_monitoring_alert_config = EmailAlertConfig(
#     user_emails=["mlopsgrp3@gmail.com"]
# )

# # Create the batch prediction job
# batch_prediction_job = aiplatform.BatchPredictionJob.create(
#     job_display_name=batch_prediction_name,
#     model_name=model_name,
#     instances_format="bigquery",
#     predictions_format="bigquery",
#     bigquery_source=input_table,
#     bigquery_destination_prefix=output_table,
#     model_parameters=None,
#     machine_type="n1-standard-4",
#     accelerator_type=None,
#     accelerator_count=None,
#     starting_replica_count=1,
#     max_replica_count=10,
#     generate_explanation=False,
#     explanation_metadata=None,
#     explanation_parameters=None,
#     encryption_spec_key_name=None,
#     sync=True,
#     model_monitoring_objective_config=model_monitoring_objective_config,
#     model_monitoring_alert_config=model_monitoring_alert_config
# )

# # Wait for the job to complete
# batch_prediction_job.wait()

# print(f"Batch prediction job completed with state: {batch_prediction_job.state}")
# print(f"Prediction results saved to: {batch_prediction_job.output_info.bigquery_output_dataset}")
# Out:
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/661148801406/locations/us-central1/batchPredictionJobs/2066989741760315392
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/661148801406/locations/us-central1/batchPredictionJobs/2066989741760315392')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/2066989741760315392?project=661148801406
# BatchPredictionJob projects/661148801406/locations/us-central1/batchPredictionJobs/2066989741760315392 current state:
# JobState.JOB_STATE_RUNNING
# BatchPredictionJob projects/661148801406/locations/us-central1/batchPredictionJobs/2066989741760315392 current state:
# JobState.JOB_STATE_RUNNING
# BatchPredictionJob projects/661148801406/locations/us-central1/batchPredictionJobs/2066989741760315392 current state:
# JobState.JOB_STATE_RUNNING
# BatchPredictionJob projects/661148801406/locations/us-central1/batchPredictionJobs/2066989741760315392 current state:
# JobState.JOB_STATE_RUNNING
# BatchPredictionJob projects/661148801406/locations/us-central1/batchPredictionJobs/2066989741760315392 current state:
# JobState.JOB_STATE_RUNNING
# BatchPredictionJob projects/661148801406/locations/us-central1/batchPredictionJobs/2066989741760315392 current state:
# JobState.JOB_STATE_RUNNING
# BatchPredictionJob projects/661148801406/locations/us-central1/batchPredictionJobs/2066989741760315392 current state:
# JobState.JOB_STATE_RUNNING
# BatchPredictionJob projects/661148801406/locations/us-central1/batchPredictionJobs/2066989741760315392 current state:
# JobState.JOB_STATE_RUNNING
# BatchPredictionJob projects/661148801406/locations/us-central1/batchPredictionJobs/2066989741760315392 current state:
# JobState.JOB_STATE_RUNNING
# BatchPredictionJob projects/661148801406/locations/us-central1/batchPredictionJobs/2066989741760315392 current state:
# JobState.JOB_STATE_SUCCEEDED
# BatchPredictionJob run completed. Resource name: projects/661148801406/locations/us-central1/batchPredictionJobs/2066989741760315392
# Batch prediction job completed with state: 4
# Prediction results saved to: bq://amazonreviewssentimentanalysis.batch_processing_input_batch_test_data
